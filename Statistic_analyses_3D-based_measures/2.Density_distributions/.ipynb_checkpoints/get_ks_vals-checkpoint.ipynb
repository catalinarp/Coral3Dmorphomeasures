# %%
import numpy as np
import scipy.stats as spy
import pandas as pd
import copy

# %%
pickle_fns = ['spheres_angles_end', 'skel_distances', 'curvatures_new']

# %%
def getAll(measure_array,id_name):
    return measure_array

def getSelection(measure_array, id_name, selection):
    ids = selection[id_name]
    return measure_array[ids]

def getPerc(measure_array, id_name,perc=2.5):
    min_s = np.percentile(measure_array,perc)
    max_s = np.percentile(measure_array,100-perc)
    return measure_array[(measure_array > min_s) & (measure_array < max_s)]

def getZ(measure_array, id_name, SD=3):
    Z = np.abs((measure_array - np.mean(measure_array))/np.std(measure_array))
    return measure_array[Z < SD]

def getSample(measure_array, n=10000):
    data = np.random.choice(measure_array, size=n, replace=True)
    return data

def getMannWhit(input_data, ids, measure_name,get_func=getAll, sample_size = None, **kwargs):
    
    size = len(ids)
    data_array = list()
    num_vals = np.zeros(size,dtype=int)
    for i in range(size):
        samp = ids[i]
        
        data_raw = input_data[samp][measure_name]
        data = get_func(data_raw,samp,**kwargs)
        if sample_size:
            data = getSample(data, sample_size)
        data_array.append(copy.deepcopy(data))
        num_vals[i] = len(data)
    stat_arr, pval_arr = calcMannWhitArray(data_array, size)
    return {'statistic':stat_arr, 'p-values': pval_arr, 'sizes': num_vals}

def calcMannWhitArray(data_arrays, size):

    stat_arr = np.zeros((size,size))
    pval_arr = np.zeros((size,size))
    for i in range(size):
        d1 = data_arrays[i]
        stat_arr[i,i], pval_arr[i,i] = spy.ks_2samp(d1,d1)
        for j in range(size):
            if j > i:
                stat, pval = spy.mannwhitneyu(d1, data_arrays[j])
                stat_arr[i,j] = stat
                stat_arr[j,i] = stat
                pval_arr[i,j] = pval
                pval_arr[j,i] = pval
            
    return stat_arr, pval_arr


def getKeys(data):
    for coral in data:
        data_arr = data[coral]
        keys = list()
        for key in data_arr:
            numbers = data_arr[key]
            if len(numbers.shape) == 1 and isinstance(numbers[0], float):
                keys.append(key)
        return keys

# %%
species_info = pd.read_csv(f'{vtk.DIR_DATA}/species_info_v1.csv')
species_info = species_info.sort_values(by='Morphospecies')
ids = list(species_info['Sample ID'])
del species_info

# %%
ks_measures = {}
for fn in pickle_fns:
    data = load_data.readPickle(fn)
    keys = getKeys(data)
    
    for key in keys:
        print(fn, key)
        ks_test = getKolSmir(data,ids,key)
        ks_measures[f'{fn}_{key}'] = copy.deepcopy(ks_test)
    del data, keys
ks_measures['ids'] = ids
load_data.writePickle(ks_measures,'ks_tests_raw')
# Out:
# spheres_angles_end da
# spheres_angles_end db
# spheres_angles_end dc
# spheres_angles_end angle
# skel_distances br_rate1
# skel_distances br_rate2
# skel_distances br_spacing1
# skel_distances br_spacing2
# curvatures_new Gauss
# curvatures_new Mean
# curvatures_new Minimum
# curvatures_new Maximum
# curvatures_new areas

# %%
print(ks_measures)
# Out:
# {'spheres_angles_end_da': {'statistic': array([[0.        , 0.37394958, 0.1629379 , ..., 0.33516404, 0.18792972,
#         0.22579107],
#        [0.37394958, 0.        , 0.32560297, ..., 0.14724465, 0.29220779,
#         0.4628588 ],
#        [0.1629379 , 0.32560297, 0.        , ..., 0.3018018 , 0.25293754,
#         0.24190823],
#        ...,
#        [0.33516404, 0.14724465, 0.3018018 , ..., 0.        , 0.25658126,
#         0.43501463],
#        [0.18792972, 0.29220779, 0.25293754, ..., 0.25658126, 0.        ,
#         0.3082968 ],
#        [0.22579107, 0.4628588 , 0.24190823, ..., 0.43501463, 0.3082968 ,
#         0.        ]]), 'p-values': array([[1.00000000e+00,

#         0.        ]]), 'p-values': array([[1.00000000e+000, 1.22124533e-015, 1.22124533e-015, ...,
#         2.34914250e-078, 1.45977924e-073, 7.31171790e-011],
#        [1.22124533e-015, 1.00000000e+000, 5.99607552e-026, ...,
#         2.58517556e-003, 1.43923817e-002, 2.41183730e-118],
#        [1.22124533e-015, 5.99607552e-026, 1.00000000e+000, ...,
#         0.00000000e+000, 8.88178420e-016, 1.45017052e-040],
#        ...,
#        [2.34914250e-078, 2.58517556e-003, 0.00000000e+000, ...,
#         1.00000000e+000, 7.73824570e-001, 3.33066907e-016],
#        [1.45977924e-073, 1.43923817e-002, 8.88178420e-016, ...,
#         7.73824570e-001, 1.00000000e+000, 3.20512530e-085],
#        [7.31171790e-011, 2.41183730e-118, 1.45017052e-040, ...,
#         3.33066907e-016, 3.20512530e-085, 1.00000000e+000]]), 'sizes': array([ 1512,   410,   683,   423,  1256,   274,   340,  1221,   274,
#          365,   660,   449,   260,   155,   460,   478,   275,   484,
#         1576,   334,  1093,   301,   522,   230,   218,   197,   743,
#          278,  3074,   106,   264,   933,   308,   480,   809,  3264,
#          248,  2499,  4807, 12482,   251,   339,   377,  2125,   972,
#          277,  1650,   603,  4286,  3168,   246,   180,  3384,   198,
#          203,   141,   187,   811,   202,   814,  1039,  1020,   232,
#          179,  3055,   749,  1958,  5297,   211,  3557,   457,   308,
#         3412,   746,   757,  2328,   180,   175,  1423])}, 'skel_distances_br_rate2': {'statistic': array([[0.        , 0.59791586, 0.3343191 , ..., 0.6973545 , 0.68619048,
#         0.12953482],
#        [0.59791586, 0.        , 0.33585687, ..., 0.16612466, 0.14404181,
#         0.61993555],
#        [0.3343191 , 0.33585687, 0.        , ..., 0.45865463, 0.45369588,
#         0.30689807],
#        ...,
#        [0.6973545 , 0.16612466, 0.45865463, ..., 0.        , 0.09492063,
#         0.73482861],
#        [0.68619048, 0.14404181, 0.45369588, ..., 0.09492063, 0.        ,
#         0.72950105],
#        [0.12953482, 0.61993555, 0.30689807, ..., 0.73482861, 0.72950105,
#         0.        ]]), 'p-values': array([[1.00000000e+000, 1.22124533e-015, 1.22124533e-015, ...,
#         6.91652692e-079, 4.59846087e-074, 3.44088091e-011],
#        [1.22124533e-015, 1.00000000e+000, 2.96337737e-026, ...,
#         1.72171235e-003, 1.08607964e-002, 2.41183730e-118],
#        [1.22124533e-015, 2.96337737e-026, 1.00000000e+000, ...,
#         0.00000000e+000, 8.88178420e-016, 4.81775026e-039],
#        ...,
#        [6.91652692e-079, 1.72171235e-003, 0.00000000e+000, ...,
#         1.00000000e+000, 3.69222751e-001, 3.33066907e-016],
#        [4.59846087e-074, 1.08607964e-002, 8.88178420e-016, ...,
#         3.69222751e-001, 1.00000000e+000, 3.20512530e-085],
#        [3.44088091e-011, 2.41183730e-118, 4.81775026e-039, ...,
#         3.33066907e-016, 3.20512530e-085, 1.00000000e+000]]), 'sizes': array([ 1512,   410,   683,   423,  1256,   274,   340,  1221,   274,
#          365,   660,   449,   260,   155,   460,   478,   275,   484,
#         1576,   334,  1093,   301,   522,   230,   218,   197,   743,
#          278,  3074,   106,   264,   933,   308,   480,   809,  3264,
#          248,  2499,  4807, 12482,   251,   339,   377,  2125,   972,
#          277,  1650,   603,  4286,  3168,   246,   180,  3384,   198,
#         59, 120, 111, 125,  49, 206, 124, 327, 110, 205,  76,  81,  88,
#         82, 106, 179,  47, 104, 118, 123,  98, 261, 131,  93, 207, 169,
#        244,  95, 154, 145, 216, 122, 107, 240, 113, 112, 231,  92,  89,
#        117,  84,  75,  66,  80,  56,  77, 139, 183, 279,  95,  87, 149,
#        232, 118, 157, 103, 159, 164,  73, 126, 117,  91, 137,  74,  77,
#        157])}, 'curvatures_new_Gauss': {'statistic': array([[0.        , 0.16655424, 0.02465876, ..., 0.09782889, 0.13915726,
#         0.02139993],
#        [0.16655424, 0.        , 0.18652159, ..., 0.07542411, 0.02752757,
#         0.1866113 ],
#        [0.02465876, 0.18652159, 0.        , ..., 0.11971739, 0.15936315,
#         0.01637731],
#        ...,
#        [0.09782889, 0.07542411, 0.11971739, ..., 0.        , 0.05272645,
#         0.11571491],
#        [0.13915726, 0.02752757, 0.15936315, ..., 0.05272645, 0.        ,
#         0.1592989 ],
#        [0.02139993, 0.1866113 , 0.01637731, ..., 0.11571491, 0.1592989 ,
#         0.        ]]), 'p-values': array([[1.00000000e+000, 0.00000000e+000, 0.00000000e+000, ...,
#         0.00000000e+000, 0.00000000e+000, 3.76353922e-277],
#        [0.00000000e+000, 1.00000000e+000, 0.00000000e+000, ...,
#         0.00000000e+000, 1.47949996e-136, 0.00000000e+000],
#        [0.00000000e+000, 0.00000000e+000, 1.00000000e+000, ...,
#         0.00000000e+000, 0.00000000e+000, 2.34288666e-154],
#        ...,
#        [0.00000000e+000, 0.00000000e+000, 0.00000000e+000, ...,
#         1.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#        [0.00000000e+000, 1.47949996e-136, 0.00000000e+000, ...,
#         0.00000000e+000, 1.00000000e+000, 0.00000000e+000],
#        [3.76353922e-277, 0.00000000e+000, 2.34288666e-154, ...,
#         0.00000000e+000, 0.00000000e+000, 1.00000000e+000]]), 'sizes': array([1612678,  487733, 1436637, 1336334, 1630417,  791151,  643521,
#         756227,  788519,  556152, 1800627, 1234534,  680412,  481472,
#         892248, 1094591,  988484,  293971, 1655689,  985589, 2316731,
#         895381, 1634449,  676491,  824720,  723957,  630157,  792311,
#         747374,  236884,  663301,  456206,  885464,  696408,  874967,
#         536978,  443754,  719821,  709986,  930562,  704474, 1017922,
#         422000,  634045,  942231,  368177, 1665629,  474619,  458168,
#         786892,  429120,  475313,  618079,  337911,  368915,  272488,
#         881172,  266728,  664871, 1119556, 1715675, 2097646,  461928,
#         290500,  757497,  933468,  441271, 1456025,  390661, 1095918,
#        1495925,  630107,  640537,  415264,  461928,  547683,  374267,
#         358968, 1223195])}, 'curvatures_new_Mean': {'statistic': array([[0.        , 0.1472966 , 0.01409613, ..., 0.09895726, 0.10908787,
#         0.00852034],
#        [0.1472966 , 0.        , 0.14378387, ..., 0.04899363, 0.04123339,
#         0.1466958 ],
#        [0.01409613, 0.14378387, 0.        , ..., 0.09641623, 0.10782712,
#         0.0094442 ],
#        ...,
#        [0.09895726, 0.04899363, 0.09641623, ..., 0.        , 0.02745356,
#         0.09871904],
#        [0.10908787, 0.04123339, 0.10782712, ..., 0.02745356, 0.        ,
#         0.10910015],
#        [0.00852034, 0.1466958 , 0.0094442 , ..., 0.09871904, 0.10910015,
#         0.        ]]), 'p-values': array([[1.00000000e+000, 0.00000000e+000, 1.44501684e-131, ...,
#         0.00000000e+000, 0.00000000e+000, 2.73071006e-044],
#        [0.00000000e+000, 1.00000000e+000, 0.00000000e+000, ...,
#         0.00000000e+000, 6.42309485e-306, 0.00000000e+000],
#        [1.44501684e-131, 0.00000000e+000, 1.00000000e+000, ...,
#         0.00000000e+000, 0.00000000e+000, 1.29830165e-051],
#        ...,
#        [0.00000000e+000, 0.00000000e+000, 0.00000000e+000, ...,
#         1.00000000e+000, 2.09695661e-120, 0.00000000e+000],
#        [0.00000000e+000, 6.42309485e-306, 0.00000000e+000, ...,
#         2.09695661e-120, 1.00000000e+000, 0.00000000e+000],
#        [2.73071006e-044, 0.00000000e+000, 1.29830165e-051, ...,
#         0.00000000e+000, 0.00000000e+000, 1.00000000e+000]]), 'sizes': array([1612678,  487733, 1436637, 1336334, 1630417,  791151,  643521,
#         756227,  788519,  556152, 1800627, 1234534,  680412,  481472,
#         892248, 1094591,  988484,  293971, 1655689,  985589, 2316731,
#         895381, 1634449,  676491,  824720,  723957,  630157,  792311,
#         747374,  236884,  663301,  456206,  885464,  696408,  874967,
#         536978,  443754,  719821,  709986,  930562,  704474, 1017922,
#         422000,  634045,  942231,  368177, 1665629,  474619,  458168,
#         786892,  429120,  475313,  618079,  337911,  368915,  272488,
#         881172,  266728,  664871, 1119556, 1715675, 2097646,  461928,
#         290500,  757497,  933468,  441271, 1456025,  390661, 1095918,
#        1495925,  630107,  640537,  415264,  461928,  547683,  374267,
#         358968, 1223195])}, 'curvatures_new_Minimum': {'statistic': array([[0.        , 0.23289336, 0.0199752 , ..., 0.14700745, 0.17771093,
#         0.0106154 ],
#        [0.23289336, 0.        , 0.2386033 , ..., 0.08861396, 0.05579762,
#         0.2423775 ],
#        [0.0199752 , 0.2386033 , 0.        , ..., 0.15426039, 0.1845518 ,
#         0.01606925],
#        ...,
#        [0.14700745, 0.08861396, 0.15426039, ..., 0.        , 0.0353624 ,
#         0.1561038 ],
#        [0.17771093, 0.05579762, 0.1845518 , ..., 0.0353624 , 0.        ,
#         0.18721303],
#        [0.0106154 , 0.2423775 , 0.01606925, ..., 0.1561038 , 0.18721303,
#         0.        ]]), 'p-values': array([[1.00000000e+000, 0.00000000e+000, 8.88841553e-264, ...,
#         0.00000000e+000, 0.00000000e+000, 1.63110957e-068],
#        [0.00000000e+000, 1.00000000e+000, 0.00000000e+000, ...,
#         0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#        [8.88841553e-264, 0.00000000e+000, 1.00000000e+000, ...,
#         0.00000000e+000, 0.00000000e+000, 1.27767990e-148],
#        ...,
#        [0.00000000e+000, 0.00000000e+000, 0.00000000e+000, ...,
#         1.00000000e+000, 1.65156879e-199, 0.00000000e+000],
#        [0.00000000e+000, 0.00000000e+000, 0.00000000e+000, ...,
#         1.65156879e-199, 1.00000000e+000, 0.00000000e+000],
#        [1.63110957e-068, 0.00000000e+000, 1.27767990e-148, ...,
#         0.00000000e+000, 0.00000000e+000, 1.00000000e+000]]), 'sizes': array([1612678,  487733, 1436637, 1336334, 1630417,  791151,  643521,
#         756227,  788519,  556152, 1800627, 1234534,  680412,  481472,
#         892248, 1094591,  988484,  293971, 1655689,  985589, 2316731,
#         895381, 1634449,  676491,  824720,  723957,  630157,  792311,
#         747374,  236884,  663301,  456206,  885464,  696408,  874967,
#         536978,  443754,  719821,  709986,  930562,  704474, 1017922,
#         422000,  634045,  942231,  368177, 1665629,  474619,  458168,
#         786892,  429120,  475313,  618079,  337911,  368915,  272488,
#         881172,  266728,  664871, 1119556, 1715675, 2097646,  461928,
#         290500,  757497,  933468,  441271, 1456025,  390661, 1095918,
#        1495925,  630107,  640537,  415264,  461928,  547683,  374267,
#         358968, 1223195])}, 'curvatures_new_Maximum': {'statistic': array([[0.        , 0.17364371, 0.02927723, ..., 0.11021277, 0.16065486,
#         0.02102524],
#        [0.17364371, 0.        , 0.1960393 , ..., 0.06450001, 0.02162111,
#         0.19350121],
#        [0.02927723, 0.1960393 , 0.        , ..., 0.1352703 , 0.1834364 ,
#         0.02317142],
#        ...,
#        [0.11021277, 0.06450001, 0.1352703 , ..., 0.        , 0.05160872,
#         0.12963484],
#        [0.16065486, 0.02162111, 0.1834364 , ..., 0.05160872, 0.        ,
#         0.18047804],
#        [0.02102524, 0.19350121, 0.02317142, ..., 0.12963484, 0.18047804,
#         0.        ]]), 'p-values': array([[1.00000000e+000, 0.00000000e+000, 0.00000000e+000, ...,
#         0.00000000e+000, 0.00000000e+000, 1.51968142e-267],
#        [0.00000000e+000, 1.00000000e+000, 0.00000000e+000, ...,
#         0.00000000e+000, 2.11308151e-084, 0.00000000e+000],
#        [0.00000000e+000, 0.00000000e+000, 1.00000000e+000, ...,
#         0.00000000e+000, 0.00000000e+000, 1.39945718e-308],
#        ...,
#        [0.00000000e+000, 0.00000000e+000, 0.00000000e+000, ...,
#         1.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#        [0.00000000e+000, 2.11308151e-084, 0.00000000e+000, ...,
#         0.00000000e+000, 1.00000000e+000, 0.00000000e+000],
#        [1.51968142e-267, 0.00000000e+000, 1.39945718e-308, ...,
#         0.00000000e+000, 0.00000000e+000, 1.00000000e+000]]), 'sizes': array([1612678,  487733, 1436637, 1336334, 1630417,  791151,  643521,
#         756227,  788519,  556152, 1800627, 1234534,  680412,  481472,
#         892248, 1094591,  988484,  293971, 1655689,  985589, 2316731,
#         895381, 1634449,  676491,  824720,  723957,  630157,  792311,
#         747374,  236884,  663301,  456206,  885464,  696408,  874967,
#         536978,  443754,  719821,  709986,  930562,  704474, 1017922,
#         422000,  634045,  942231,  368177, 1665629,  474619,  458168,
#         786892,  429120,  475313,  618079,  337911,  368915,  272488,
#         881172,  266728,  664871, 1119556, 1715675, 2097646,  461928,
#         290500,  757497,  933468,  441271, 1456025,  390661, 1095918,
#        1495925,  630107,  640537,  415264,  461928,  547683,  374267,
#         358968, 1223195])}, 'curvatures_new_areas': {'statistic': array([[0.        , 0.79449522, 0.01823903, ..., 0.78197899, 0.79148275,
#         0.03661944],
#        [0.79449522, 0.        , 0.77632158, ..., 0.02124681, 0.02024827,
#         0.7580535 ],
#        [0.01823903, 0.77632158, 0.        , ..., 0.76377183, 0.77326641,
#         0.03232246],
#        ...,
#        [0.78197899, 0.02124681, 0.76377183, ..., 0.        , 0.01131496,
#         0.74556234],
#        [0.79148275, 0.02024827, 0.77326641, ..., 0.01131496, 0.        ,
#         0.75504878],
#        [0.03661944, 0.7580535 , 0.03232246, ..., 0.74556234, 0.75504878,
#         0.        ]]), 'p-values': array([[1.00000000e+000, 0.00000000e+000, 5.51273382e-220, ...,
#         0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#        [0.00000000e+000, 1.00000000e+000, 0.00000000e+000, ...,
#         1.78738920e-083, 4.47793365e-074, 0.00000000e+000],
#        [5.51273382e-220, 0.00000000e+000, 1.00000000e+000, ...,
#         0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#        ...,
#        [0.00000000e+000, 1.78738920e-083, 0.00000000e+000, ...,
#         1.00000000e+000, 8.34487880e-021, 0.00000000e+000],
#        [0.00000000e+000, 4.47793365e-074, 0.00000000e+000, ...,
#         8.34487880e-021, 1.00000000e+000, 0.00000000e+000],
#        [0.00000000e+000, 0.00000000e+000, 0.00000000e+000, ...,
#         0.00000000e+000, 0.00000000e+000, 1.00000000e+000]]), 'sizes': array([1612678,  487733, 1436637, 1336334, 1630417,  791151,  643521,
#         756227,  788519,  556152, 1800627, 1234534,  680412,  481472,
#         892248, 1094591,  988484,  293971, 1655689,  985589, 2316731,
#         895381, 1634449,  676491,  824720,  723957,  630157,  792311,
#         747374,  236884,  663301,  456206,  885464,  696408,  874967,
#         536978,  443754,  719821,  709986,  930562,  704474, 1017922,
#         422000,  634045,  942231,  368177, 1665629,  474619,  458168,
#         786892,  429120,  475313,  618079,  337911,  368915,  272488,
#         881172,  266728,  664871, 1119556, 1715675, 2097646,  461928,
#         290500,  757497,  933468,  441271, 1456025,  390661, 1095918,
#        1495925,  630107,  640537,  415264,  461928,  547683,  374267,
#         358968, 1223195])}}

# %%
def prepareSelection(fn_selection, selection_name, ids):
    selection = load_data.readPickle(fn_selection)
    selection_dict = {}
    for coral_id in ids:
        selection_dict[coral_id] = selection[coral_id][selection_name]
    return selection_dict

# %%
selection_combos = {
    'long': {
        'fn_choose': 'skel_distances',
        'selections': 'long_enough',
        'data': 'skel_distances',
        'measures': ['br_rate1', 'br_rate2'],
        'sample_size': 70 
    },
    'tips': {
        'fn_choose': 'poly_ends',
        'selections': 'point_ids',
        'data': 'curvatures_new',
        'measures': ['Mean','Gauss', 'Minimum', 'Maximum'],
        'sample_size': 10000
    }
    
}

# %%
measures_dict = {}

for select_method in selection_combos:
    select_array = selection_combos[select_method]
    print(select_array)
    data_name = select_array['data']
    data = load_data.readPickle(data_name)
    measures = select_array['measures']
    if measures == 'all':
        measures = getKeys(data)
    selection = prepareSelection(select_array['fn_choose'], select_array['selections'],ids)
    for key in measures:
        print(data_name, key)
        ks_test = getKolSmir(data,ids,key,get_func=getSelection, selection=selection, sample_size = select_array['sample_size'])
        ks_measures[f'{data_name}_{key}_{select_method}'] = copy.deepcopy(ks_test)
    del data, selection
ks_measures['ids'] = ids        
load_data.writePickle(ks_measures,'ks_tests_selection_sample')
# Out:
# {'fn_choose': 'skel_distances', 'selections': 'long_enough', 'data': 'skel_distances', 'measures': ['br_rate1', 'br_rate2'], 'sample_size': 70}
# skel_distances br_rate1
# skel_distances br_rate2
# {'fn_choose': 'poly_ends', 'selections': 'point_ids', 'data': 'curvatures_new', 'measures': 'all', 'sample_size': 10000}
# curvatures_new Gauss
# curvatures_new Mean
# curvatures_new Minimum
# curvatures_new Maximum
# curvatures_new areas

# %%
ks_measures = {}
ss = 50
for fn in pickle_fns:
    if fn == 'curvatures_new':
        ss = 70000
    data = load_data.readPickle(fn)
    keys = getKeys(data)
    
    for key in keys:
        print(fn, key)
        ks_test = getKolSmir(data,ids,key, sample_size=ss)
        ks_measures[f'{fn}_{key}'] = copy.deepcopy(ks_test)
    del data, keys
ks_measures['ids'] = ids
load_data.writePickle(ks_measures,'ks_tests_sample2')
# Out:
# spheres_angles_end da
# spheres_angles_end db
# spheres_angles_end dc
# spheres_angles_end angle
# skel_distances br_rate1
# skel_distances br_rate2
# skel_distances br_spacing1
# skel_distances br_spacing2
# curvatures_new Gauss
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-8ec28dac1ed4> in <module>
#       9     for key in keys:
#      10         print(fn, key)
# ---> 11         ks_test = getKolSmir(data,ids,key, sample_size=ss)
#      12         ks_measures[f'{fn}_{key}'] = copy.deepcopy(ks_test)
#      13     del data, keys
#
# <ipython-input-12-ad2d6026f2fe> in getKolSmir(input_data, ids, measure_name, get_func, sample_size, **kwargs)
#      33         data_array.append(copy.deepcopy(data))
#      34         num_vals[i] = len(data)
# ---> 35     stat_arr, pval_arr = calcKolSmirArray(data_array, size)
#      36     return {'statistic':stat_arr, 'p-values': pval_arr, 'sizes': num_vals}
#      37
#
# <ipython-input-12-ad2d6026f2fe> in calcKolSmirArray(data_arrays, size)
#      45         for j in range(size):
#      46             if j > i:
# ---> 47                 stat, pval = spy.ks_2samp(d1, data_arrays[j])
#      48                 stat_arr[i,j] = stat
#      49                 stat_arr[j,i] = stat
#
# ~/.local/lib/python3.8/site-packages/scipy/stats/stats.py in ks_2samp(data1, data2, alternative, mode)
#    6820     if np.ma.is_masked(data2):
#    6821         data2 = data2.compressed()
# -> 6822     data1 = np.sort(data1)
#    6823     data2 = np.sort(data2)
#    6824     n1 = data1.shape[0]
#
# <__array_function__ internals> in sort(*args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py in sort(a, axis, kind, order)
#     994     else:
#     995         a = asanyarray(a).copy(order="K")
# --> 996     a.sort(axis=axis, kind=kind, order=order)
#     997     return a
#     998
#
# KeyboardInterrupt:

# %%
Z = 3
ks_measures = {}
for fn in pickle_fns:
    data = load_data.readPickle(fn)
    keys = getKeys(data)
    for key in keys:
        print(fn,key)
        ks_test = getKolSmir(data,ids,key, get_func = getZ, SD=Z)
        ks_measures[f'{fn}_{key}'] = copy.deepcopy(ks_test)
    del data, keys
ks_measures['ids'] = ids
load_data.writePickle(ks_measures,f'ks_tests_Z_{Z}')
# Out:
# spheres_angles_end da
# spheres_angles_end db
# spheres_angles_end dc
# spheres_angles_end angle
# skel_distances br_rate1
# skel_distances br_rate2
# skel_distances br_spacing1
# skel_distances br_spacing2
# curvatures_new Gauss
# curvatures_new Mean
# curvatures_new Minimum
# curvatures_new Maximum
# curvatures_new areas

# %%
measure_dict = {}
for fn in pickle_fns:
    data = load_data.readPickle(fn)
    keys = getKeys(data)
    for key in keys:
        print(fn,key)
        ks_test = getKolSmir(data,ids,key, get_func = getZ, SD=Z)
        ks_measures[f'{fn}_{key}'] = copy.deepcopy(ks_test)
    del data, keys
ks_measures['ids'] = ids
load_data.writePickle(ks_measures,f'ks_tests_Z_{Z}')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LogNorm

# %%
ks_m = load_data.readPickle('ks_tests_selection_sample')    
species_info = pd.read_csv(f'{vtk.DIR_DATA}/species_info_v1.csv')
ids = ks_m['ids']
size = len(ids)
species_relevant = [species_info[species_info['Sample ID'] == ids[i]]['Morphospecies'].values[0] for i in range(size)]

sp_to_col = {'bifurcata':'blue', 'hyacinthus':"orange", 'cytherea':'green'}
colors = [sp_to_col[species] for species in species_relevant]
for key in ks_m:
    print(key)
    if key == 'ids':
        continue
    for typ in ['p-values']:

        plt.figure(figsize = (5,5))
        plt.title(f'{key} {typ}')
        cmap = sns.color_palette("Greys", as_cmap = True)
        cmap.set_under('purple')
        g = sns.heatmap(ks_m[key][typ], xticklabels=ids, yticklabels=ids,cmap=cmap, vmin=0.05, cbar_kws={'extend':'min'})
        for i,tick_label in enumerate(g.axes.get_yticklabels()):
            tick_label.set_color(colors[i])
            tick_label.set_fontsize("12")
        for i,tick_label in enumerate(g.axes.get_xticklabels()):
            tick_label.set_color(colors[i])
        
        #plt.savefig(f'{vtk.DIR_FIG}/ks_{key}_{typ}_sample2.png')
        #plt.close()
        plt.show()
# Out:
# spheres_angles_end_da
# <ipython-input-64-e37029d807dd>:18: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("Greys"))
#   cmap.set_under('purple')
# spheres_angles_end_db
# spheres_angles_end_dc
# spheres_angles_end_angle
# skel_distances_br_rate1
# skel_distances_br_rate2
# skel_distances_br_spacing1
# skel_distances_br_spacing2
# skel_distances_br_rate1_long
# skel_distances_br_rate2_long
# curvatures_new_Gauss_tips
# curvatures_new_Mean_tips
# curvatures_new_Minimum_tips
# curvatures_new_Maximum_tips
# curvatures_new_areas_tips
# ids

# %%
ks_measures = {}
ss = 1000
  
for fn in pickle_fns:
    data = load_data.readPickle(fn)
    keys = getKeys(data)
    for i in range(10):
        for key in keys:
            print(key)
            ks_test = getKolSmir(data,ids,key, sample_size=ss)
            np.savetxt(f"{vtk.DIR_RESULTS}/ks_{fn}_{key}_size{ss}_{i}.csv", ks_test['p-values'], delimiter=",")
    del data, keys
# Out:
# da
# db
# dc
# angle
# da
# db
# dc
# angle
# da
# db
# dc
# angle
# da
# db
# dc
# angle
# da
# db
# dc
# angle
# da
# db
# dc
# angle
# da
# db
# dc
# angle
# da
# db
# dc
# angle
# da
# db
# dc
# angle
# da
# db
# dc
# angle
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# Gauss
# Mean
# Minimum
# Maximum
# areas
# Gauss
# Mean
# Minimum
# Maximum
# areas
# Gauss
# Mean
# Minimum
# Maximum
# areas
# Gauss
# Mean
# Minimum
# Maximum
# areas
# Gauss
# Mean
# Minimum
# Maximum
# areas
# Gauss
# Mean
# Minimum
# Maximum
# areas
# Gauss
# Mean
# Minimum
# Maximum
# areas
# Gauss
# Mean
# Minimum
# Maximum
# areas
# Gauss
# Mean
# Minimum
# Maximum
# areas
# Gauss
# Mean
# Minimum
# Maximum
# areas

# %%
ss = 1000
for select_method in selection_combos:
    select_array = selection_combos[select_method]
    print(select_array)
    data_name = select_array['data']
    data = load_data.readPickle(data_name)
    measures = select_array['measures']
    selection = prepareSelection(select_array['fn_choose'], select_array['selections'],ids)
    for i in range(10): 
        for key in measures:
            print(key)
            ks_test = getKolSmir(data,ids,key,get_func=getSelection, selection=selection, sample_size = ss)
            np.savetxt(f"{vtk.DIR_RESULTS}/ks_{data_name}_{key}_{select_method}_size{ss}_{i}.csv", ks_test['p-values'], delimiter=",")
    del data, selection
# Out:
# {'fn_choose': 'skel_distances', 'selections': 'long_enough', 'data': 'skel_distances', 'measures': ['br_rate1', 'br_rate2'], 'sample_size': 70}
# br_rate1
# br_rate2
# br_rate1
# br_rate2
# br_rate1
# br_rate2
# br_rate1
# br_rate2
# br_rate1
# br_rate2
# br_rate1
# br_rate2
# br_rate1
# br_rate2
# br_rate1
# br_rate2
# br_rate1
# br_rate2
# br_rate1
# br_rate2
# {'fn_choose': 'poly_ends', 'selections': 'point_ids', 'data': 'curvatures_new', 'measures': ['Mean', 'Gauss', 'Minimum', 'Maximum'], 'sample_size': 10000}
# Mean
# Gauss
# Minimum
# Maximum
# Mean
# Gauss
# Minimum
# Maximum
# Mean
# Gauss
# Minimum
# Maximum
# Mean
# Gauss
# Minimum
# Maximum
# Mean
# Gauss
# Minimum
# Maximum
# Mean
# Gauss
# Minimum
# Maximum
# Mean
# Gauss
# Minimum
# Maximum
# Mean
# Gauss
# Minimum
# Maximum
# Mean
# Gauss
# Minimum
# Maximum
# Mean
# Gauss
# Minimum
# Maximum

# %%
import csv
ids1 = [ids]
with open(f'{vtk.DIR_RESULTS}/ks_ids.csv', 'w') as csvfile:
    writer = csv.writer(csvfile, delimiter=',')
    print(ids1)
    writer.writerows(ids1)
# Out:
# [['15Oki01', '18Oki13', '18Oki15', '18Oki16', '18Oki17', '18Oki18', '18Oki31', '18Oki32', '15Oki29', '18Oki33', '18Oki35', '18Oki36', '19Oki12', '19Oki14', '19Oki20', '19Oki22', '19Oki23', '18Oki34', '15Oki24', '18Oki14', '15Oki22', '15Oki23', '15Oki12', '15Oki14', '15Oki08', '15Oki06', '15Oki16', '15Oki03', '19Oki09', '19Oki07', '19Oki17', '19Oki18', '15Oki10', '15Oki04', '18Oki30', '18Oki29', '18Oki28', '18Oki27', '18Oki26', '18Oki25', '15Oki05', '15Oki09', '19Oki25', '18Oki10', '15Oki27', '18Oki07', '15Oki19', '18Oki12', '18Oki11', '18Oki09', '18Oki08', '18Oki02', '18Oki01', '19Oki13', '15Oki40', '19Oki15', '15Oki17', '19Oki16', '15Oki21', '15Oki26', '15Oki25', '15Oki02', '18Oki03', '19Oki05', '18Oki05', '19Oki01', '18Oki04', '15Oki15', '18Oki06', '15Oki11', '15Oki13', '19Oki24', '18Oki23', '18Oki22', '18Oki21', '18Oki20', '18Oki19', '19Oki02', '18Oki24']]

# %% [markdown]
# # KS but mannwitney

# %%
ks_measures = {}
ss = 1000
  
for fn in pickle_fns:
    data = load_data.readPickle(fn)
    keys = getKeys(data)
    for i in range(10):
        for key in keys:
            print(key)
            ks_test = getMannWhit(data,ids,key, sample_size=ss)
            np.savetxt(f"{vtk.DIR_RESULTS}/mwpval/manwhit_{fn}_{key}_size{ss}_{i}.csv", ks_test['p-values'], delimiter=",")
            np.savetxt(f"{vtk.DIR_RESULTS}/mwstat/manwhit_{fn}_{key}_size{ss}_{i}.csv", ks_test['statistic'], delimiter=",")
    del data, keys
# Out:
# da
# db
# dc
# angle
# da
# db
# dc
# angle
# da
# db
# dc
# angle
# da
# db
# dc
# angle
# da
# db
# dc
# angle
# da
# db
# dc
# angle
# da
# db
# dc
# angle
# da
# db
# dc
# angle
# da
# db
# dc
# angle
# da
# db
# dc
# angle
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# br_rate1
# br_rate2
# br_spacing1
# br_spacing2
# Gauss
# Mean
# Minimum
# Maximum
# areas
# Gauss
# Mean
# Minimum
# Maximum
# areas
# Gauss
# Mean
# Minimum
# Maximum
# areas
# Gauss
# Mean
# Minimum
# Maximum
# areas
# Gauss
# Mean
# Minimum
# Maximum
# areas
# Gauss
# Mean
# Minimum
# Maximum
# areas
# Gauss
# Mean
# Minimum
# Maximum
# areas
# Gauss
# Mean
# Minimum
# Maximum
# areas
# Gauss
# Mean
# Minimum
# Maximum
# areas
# Gauss
# Mean
# Minimum
# Maximum
# areas

# %%
ss = 1000
for select_method in selection_combos:
    select_array = selection_combos[select_method]
    print(select_array)
    data_name = select_array['data']
    data = load_data.readPickle(data_name)
    measures = select_array['measures']
    selection = prepareSelection(select_array['fn_choose'], select_array['selections'],ids)
    for i in range(10): 
        for key in measures:
            print(key)
            ks_test = getMannWhit(data,ids,key,get_func=getSelection, selection=selection, sample_size = ss)
            np.savetxt(f"{vtk.DIR_RESULTS}/mwpval/manwhit_{data_name}_{key}_{select_method}_size{ss}_{i}.csv", ks_test['p-values'], delimiter=",")
            np.savetxt(f"{vtk.DIR_RESULTS}/mwstat/manwhit_{data_name}_{key}_{select_method}_size{ss}_{i}.csv", ks_test['statistic'], delimiter=",")
    del data, selection
# Out:
# {'fn_choose': 'skel_distances', 'selections': 'long_enough', 'data': 'skel_distances', 'measures': ['br_rate1', 'br_rate2'], 'sample_size': 70}
# br_rate1
# br_rate2
# br_rate1
# br_rate2
# br_rate1
# br_rate2
# br_rate1
# br_rate2
# br_rate1
# br_rate2
# br_rate1
# br_rate2
# br_rate1
# br_rate2
# br_rate1
# br_rate2
# br_rate1
# br_rate2
# br_rate1
# br_rate2
# {'fn_choose': 'poly_ends', 'selections': 'point_ids', 'data': 'curvatures_new', 'measures': ['Mean', 'Gauss', 'Minimum', 'Maximum'], 'sample_size': 10000}
# Mean
# Gauss
# Minimum
# Maximum
# Mean
# Gauss
# Minimum
# Maximum
# Mean
# Gauss
# Minimum
# Maximum
# Mean
# Gauss
# Minimum
# Maximum
# Mean
# Gauss
# Minimum
# Maximum
# Mean
# Gauss
# Minimum
# Maximum
# Mean
# Gauss
# Minimum
# Maximum
# Mean
# Gauss
# Minimum
# Maximum
# Mean
# Gauss
# Minimum
# Maximum
# Mean
# Gauss
# Minimum
# Maximum

# %%
import csv
ids1 = [ids]
with open(f'{vtk.DIR_RESULTS}/manwhit_ids.csv', 'w') as csvfile:
    writer = csv.writer(csvfile, delimiter=',')
    print(ids1)
    writer.writerows(ids1)
# Out:
# [['15Oki01', '18Oki13', '18Oki15', '18Oki16', '18Oki17', '18Oki18', '18Oki31', '18Oki32', '15Oki29', '18Oki33', '18Oki35', '18Oki36', '19Oki12', '19Oki14', '19Oki20', '19Oki22', '19Oki23', '18Oki34', '15Oki24', '18Oki14', '15Oki22', '15Oki23', '15Oki12', '15Oki14', '15Oki08', '15Oki06', '15Oki16', '15Oki03', '19Oki09', '19Oki07', '19Oki17', '19Oki18', '15Oki10', '15Oki04', '18Oki30', '18Oki29', '18Oki28', '18Oki27', '18Oki26', '18Oki25', '15Oki05', '15Oki09', '19Oki25', '18Oki10', '15Oki27', '18Oki07', '15Oki19', '18Oki12', '18Oki11', '18Oki09', '18Oki08', '18Oki02', '18Oki01', '19Oki13', '15Oki40', '19Oki15', '15Oki17', '19Oki16', '15Oki21', '15Oki26', '15Oki25', '15Oki02', '18Oki03', '19Oki05', '18Oki05', '19Oki01', '18Oki04', '15Oki15', '18Oki06', '15Oki11', '15Oki13', '19Oki24', '18Oki23', '18Oki22', '18Oki21', '18Oki20', '18Oki19', '19Oki02', '18Oki24']]
