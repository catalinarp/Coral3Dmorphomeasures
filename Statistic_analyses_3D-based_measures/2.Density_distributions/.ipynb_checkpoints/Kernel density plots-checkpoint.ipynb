# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors import KernelDensity
from scipy import stats
import pandas as pd

# %%
FIG_DIM = 5
DPI = 300
AX_FONT = 14
TICK_FONT = 12

# %%
def getKernelDensityAll(data, species_info, measure,selection_data = None, selection_key = None,weights_key=None, min_val = 0, 
                     max_val = 1,n_steps=1000):
    lines = {}
    for key in species_info['Sample ID']:
        print(key)
        values = data[key][measure]
        if selection_key:
            selection_ids = selection_data[key][selection_key]
        else: 
            selection_ids = np.arange(len(values))
        
        values = values[selection_ids]
        if weights_key:
            weight = data[key][weights_key]
            weight = weight[selection_ids]
        else: 
            weight = None
        
        kde = getKernelDensityEstimator(values, weight)
        test_vals = np.linspace(min_val, max_val, n_steps)
        pdf = kde(test_vals)
        #log_likely = kde.score_samples(test_vals[:,None])
        lines[key] = pdf
    return lines, [min_val, max_val, n_steps]

def getKernelDensityEstimator(values, weights):
    nparam_density = stats.kde.gaussian_kde(values,weights = weights)
    print(nparam_density.factor)
    #x = np.linspace(-20, 10, 200)
    #nparam_density = nparam_density(x)
    #kde = KernelDensity(bandwidth=bw, kernel = 'gaussian')
    #kde.fit(values[:,None], y=None, sample_weight=weights)
    return nparam_density
    
def getLikelyPerSpecies(lines, species_info):
    specs = ['bifurcata', 'cytherea', 'hyacinthus']
    species_relevant = [species_info[species_info['Morphospecies'] == spec]['Sample ID'].values for spec in specs]
    results  = {}
    for x in range(3):
        IDS = species_relevant[x]
        vals = np.zeros((len(IDS),len(lines[IDS[0]])))
        for i,sp in enumerate(IDS):
            vals[i] = lines[sp]
        results[specs[x]] = {
            'mean': np.mean(vals, axis = 0),
            'SD': np.std(vals, axis = 0)
        }
    return results

def plotKDE(lines, rang,species_info, xlabel,xlim=None):
    if xlim == None:
        xlim = (rang[0], rang[1])
    per_spec = getLikelyPerSpecies(lines, species_info)
    x = np.linspace(rang[0], rang[1], rang[2])
    colors = {'bifurcata':'#1f77b4', 'cytherea':'#2ca02c','hyacinthus':'#ff7f0e'}

    fig = plt.figure(figsize=(5,5))
    for key in per_spec:
        data = per_spec[key]
        plt.plot(x,data['mean'], color = colors[key], label = key)
        plt.fill_between(x, data['mean'] - data['SD'], data['mean']+ data['SD'],
                        alpha = .2, color = colors[key])
    plt.xlabel(xlabel, fontsize=AX_FONT)
    plt.ylabel('density', fontsize = AX_FONT)
    plt.legend(fontsize = AX_FONT)
    plt.tick_params(axis='both', which='major', labelsize=TICK_FONT)
    plt.grid()
    plt.xlim(xlim)
    plt.ylim(0)
    plt.tight_layout()
    return fig

# %%
species_info = pd.read_csv(f'{vtk.DIR_DATA}/species_info_v1.csv')
species_info.head()
# Out:
#   Sample ID  Collection year     Genus Open nomenclature Morphospecies  \
# 0   15Oki01             2015  Acropora              aff.     bifurcata
# 1   15Oki02             2015  Acropora              aff.    hyacinthus
# 2   15Oki03             2015  Acropora              aff.     bifurcata
# 3   15Oki04             2015  Acropora              aff.      cytherea
# 4   15Oki05             2015  Acropora              aff.      cytherea
#
#    Dataset
# 0  Testing
# 1  Testing
# 2  Testing
# 3  Testing
# 4  Testing

# %% [markdown]
# # Spheres and angles

# %%
sphere_data = load_data.readPickle('spheres_angles_end')
spheres =['da', 'db','dc','angle'] 
max_val = [1.7, 1.2, 1.1,3]
for i,sphere in enumerate(spheres):
    lines, rang = getKernelDensityAll(sphere_data, species_info, sphere,max_val = max_val[i])
    load_data.writePickle({'lines':lines, 'range': rang}, f'KD_estimation/KDE_{sphere}')
# Out:
# 15Oki01
# 15Oki02
# 15Oki03
# 15Oki04
# 15Oki05
# 15Oki06
# 15Oki08
# 15Oki09
# 15Oki10
# 15Oki11
# 15Oki12
# 15Oki13
# 15Oki14
# 15Oki15
# 15Oki16
# 15Oki17
# 15Oki19
# 15Oki21
# 15Oki22
# 15Oki23
# 15Oki24
# 15Oki25
# 15Oki26
# 15Oki27
# 15Oki29
# 15Oki40
# 18Oki01
# 18Oki02
# 18Oki03
# 18Oki04
# 18Oki05
# 18Oki06
# 18Oki07
# 18Oki08
# 18Oki09
# 18Oki10
# 18Oki11
# 18Oki12
# 18Oki13
# 18Oki14
# 18Oki15
# 18Oki16
# 18Oki17
# 18Oki18
# 18Oki19
# 18Oki20
# 18Oki21
# 18Oki22
# 18Oki23
# 18Oki24
# 18Oki25
# 18Oki26
# 18Oki27
# 18Oki28
# 18Oki29
# 18Oki30
# 18Oki31
# 18Oki32
# 18Oki33
# 18Oki34
# 18Oki35
# 18Oki36
# 19Oki01
# 19Oki02
# 19Oki05
# 19Oki07
# 19Oki09
# 19Oki12
# 19Oki13
# 19Oki14
# 19Oki15
# 19Oki16
# 19Oki17
# 19Oki18
# 19Oki20
# 19Oki22
# 19Oki23
# 19Oki24
# 19Oki25
# 15Oki01
# 15Oki02
# 15Oki03
# 15Oki04
# 15Oki05
# 15Oki06
# 15Oki08
# 15Oki09
# 15Oki10
# 15Oki11
# 15Oki12
# 15Oki13
# 15Oki14
# 15Oki15
# 15Oki16
# 15Oki17
# 15Oki19
# 15Oki21
# 15Oki22
# 15Oki23
# 15Oki24
# ...

# %%
for sphere in spheres:
    data = load_data.readPickle(f'KD_estimation/KDE_{sphere}_bw{bw}')
    data2 = load_data.readPickle(f'KD_estimation/KDE_{sphere}')
    lines = data['lines']
    lines2 = data2['lines']
    rang = data['range']
    fig = plotKDE(lines2, rang, species_info,xlabel = f'{sphere} (cm)')
    plt.savefig(f'{vtk.DIR_FIG}/KDE/KDE_{sphere}.pdf', dpi = DPI)

# %% [markdown]
# # Curvatures new

# %%
curv_data = load_data.readPickle('curvatures_new')
poly_ends = load_data.readPickle('poly_ends')

# %%
# Obtain KDE
till = [60,400,60,60]
for i,curv in enumerate(['Mean', 'Gauss', 'Minimum', 'Maximum']):
    lines, rang = getKernelDensityAll(curv_data, species_info, curv, weights_key = 'areas', min_val = -till[i], max_val = till[i])
    load_data.writePickle({'lines':lines, 'range': rang}, f'KD_estimation/KDE_{curv}')
# Out:
# 15Oki01
# 0.05985136819585495
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-82d5c4890e15> in <module>
#       2 till = [60,400,60,60]
#       3 for i,curv in enumerate(['Mean', 'Gauss', 'Minimum', 'Maximum']):
# ----> 4     lines, rang = getKernelDensityAll(curv_data, species_info, curv, weights_key = 'areas', min_val = -till[i], max_val = till[i])
#       5     load_data.writePickle({'lines':lines, 'range': rang}, f'KD_estimation/KDE_{curv}')
#
# <ipython-input-7-83e8a1eadc33> in getKernelDensityAll(data, species_info, measure, selection_data, selection_key, weights_key, min_val, max_val, n_steps)
#      19         kde = getKernelDensityEstimator(values, weight)
#      20         test_vals = np.linspace(min_val, max_val, n_steps)
# ---> 21         pdf = kde(test_vals)
#      22         #log_likely = kde.score_samples(test_vals[:,None])
# ...

# %%
# Plot KDE
labels = [r'$H$ ($cm^{-1}$)','$K$ ($cm^{-2}$)','$k_{2}$ ($cm^{-1}$)', '$k_{1}$ ($cm^{-1}$)']
for i,curv in enumerate(['Mean', 'Gauss','Minimum','Maximum']):
    print(curv)
    data = load_data.readPickle(f'KD_estimation/KDE_{curv}')
    lines = data['lines']
    rang = data['range']
    print(rang)
    fig = plotKDE(lines, rang, species_info,xlabel = labels[i])
    plt.savefig(f'{vtk.DIR_FIG}/KDE/KDE_{curv}.pdf', dpi = DPI)
# Out:
# Mean
# [-60, 60, 1000]
# Gauss
# [-400, 400, 1000]
# Minimum
# [-60, 60, 1000]
# Maximum
# [-60, 60, 1000]

# %%
# Obtain KDE
#till = [60,300,60,60]
till = [400]
#for i,curv in enumerate(['Mean','Gauss', 'Minimum', 'Maximum']):
for i,curv in enumerate(['Gauss']):
    
    lines, rang = getKernelDensityAll(curv_data, species_info, curv, selection_data = poly_ends, selection_key = 'point_ids',weights_key = 'areas',min_val = -till[i], max_val = till[i])
    load_data.writePickle({'lines':lines, 'range': rang}, f'KD_estimation/KDE_{curv}_end')
# Out:
# 15Oki01
# 0.08267232018843447
# 15Oki02
# 0.07944379250502177
# 15Oki03
# 0.10085163803045268
# 15Oki04
# 0.10359176447023015
# 15Oki05
# 0.10884235874822473
# 15Oki06
# 0.09557661937763699
# 15Oki08
# 0.10079742648973072
# 15Oki09
# 0.09143056633346558
# 15Oki10
# 0.09807357791273058
# 15Oki11
# 0.08886516760631892
# 15Oki12
# 0.08851347041688125
# 15Oki13
# 0.08413645996388804
# 15Oki14
# 0.10880192060009848
# 15Oki15
# 0.0814388014654925
# 15Oki16
# 0.10135423082839706
# 15Oki17
# 0.09999554632648376
# 15Oki19
# 0.0872885269344998
# 15Oki21
# 0.10445360950261641
# 15Oki22
# 0.08251266233482821
# 15Oki23
# 0.10105122508341335
# 15Oki24
# 0.08988624828625594
# 15Oki25
# 0.08146221021384116
# 15Oki26
# 0.09314703585916678
# 15Oki27
# 0.09947076153919115
# 15Oki29
# 0.10944533154947221
# 15Oki40
# 0.11604463043033701
# 18Oki01
# 0.09417384890512773
# 18Oki02
# 0.0998819952801293
# 18Oki03
# 0.11318194998581313
# 18Oki04
# 0.1009905480986793
# 18Oki05
# 0.1105742471873106
# 18Oki06
# ...

# %%
# Plot KDE
#bw = 2
labels = [r'$H_{tip}$($cm^{-1}$)','$K_{tip}$ ($cm^{-2}$)','$k_{2,tip}$ ($cm^{-1}$)', '$k_{1,tip}$ ($cm^{-1}$)']
for i,curv in enumerate(['Mean', 'Gauss','Minimum','Maximum']):
    print(curv)
    data = load_data.readPickle(f'KD_estimation/KDE_{curv}_end')
    lines = data['lines']
    rang = data['range']
    print(rang)
    fig = plotKDE(lines, rang, species_info,xlabel = labels[i])
    plt.savefig(f'{vtk.DIR_FIG}/KDE/KDE_{curv}_end.pdf', dpi = DPI)
# Out:
# Mean
# [-60, 60, 1000]
# Gauss
# [-400, 400, 1000]
# Minimum
# [-60, 60, 1000]
# Maximum
# [-60, 60, 1000]

# %% [markdown]
# # Skel distances

# %%
skel_dist = load_data.readPickle('skel_distances')

# %%
lengths =['br_rate1', 'br_rate2']
max_val = [3, 3, 3,3]
for i,length in enumerate(lengths):
    lines, rang = getKernelDensityAll(skel_dist, species_info, length,selection_data =skel_dist, selection_key = 'long_enough',weights_key=None, min_val = 0, 
                     max_val = max_val[i],n_steps=1000)
    load_data.writePickle({'lines':lines, 'range': rang}, f'KD_estimation/KDE_{length}')
# Out:
# 15Oki01
# 15Oki02
# 15Oki03
# 15Oki04
# 15Oki05
# 15Oki06
# 15Oki08
# 15Oki09
# 15Oki10
# 15Oki11
# 15Oki12
# 15Oki13
# 15Oki14
# 15Oki15
# 15Oki16
# 15Oki17
# 15Oki19
# 15Oki21
# 15Oki22
# 15Oki23
# 15Oki24
# 15Oki25
# 15Oki26
# 15Oki27
# 15Oki29
# 15Oki40
# 18Oki01
# 18Oki02
# 18Oki03
# 18Oki04
# 18Oki05
# 18Oki06
# 18Oki07
# 18Oki08
# 18Oki09
# 18Oki10
# 18Oki11
# 18Oki12
# 18Oki13
# 18Oki14
# 18Oki15
# 18Oki16
# 18Oki17
# 18Oki18
# 18Oki19
# 18Oki20
# 18Oki21
# 18Oki22
# 18Oki23
# 18Oki24
# 18Oki25
# 18Oki26
# 18Oki27
# 18Oki28
# 18Oki29
# 18Oki30
# 18Oki31
# 18Oki32
# 18Oki33
# 18Oki34
# 18Oki35
# 18Oki36
# 19Oki01
# 19Oki02
# 19Oki05
# 19Oki07
# 19Oki09
# 19Oki12
# 19Oki13
# 19Oki14
# 19Oki15
# 19Oki16
# 19Oki17
# 19Oki18
# 19Oki20
# 19Oki22
# 19Oki23
# 19Oki24
# 19Oki25
# 15Oki01
# 15Oki02
# 15Oki03
# 15Oki04
# 15Oki05
# 15Oki06
# 15Oki08
# 15Oki09
# 15Oki10
# 15Oki11
# 15Oki12
# 15Oki13
# 15Oki14
# 15Oki15
# 15Oki16
# 15Oki17
# 15Oki19
# 15Oki21
# 15Oki22
# 15Oki23
# 15Oki24
# ...

# %%
labels = [r'$br_{length}$ ($cm$)',r'$br_{rate}$ ($cm$)']
for i,sphere in enumerate(['br_rate1', 'br_rate2']):
    data = load_data.readPickle(f'KD_estimation/KDE_{sphere}')
    lines = data['lines']
    rang = data['range']
    fig = plotKDE(lines, rang, species_info,xlabel = labels[i])
    plt.savefig(f'{vtk.DIR_FIG}/KDE/KDE_{sphere}.pdf', dpi = DPI)

# %%
lengths =['br_spacing1', 'br_spacing2']
max_val = [1.5, 1.5]
for i,length in enumerate(lengths):
    lines, rang= getKernelDensityAll(skel_dist, species_info, length,weights_key=None, min_val = 0, 
                     max_val = max_val[i],n_steps=1000)
    load_data.writePickle({'lines':lines, 'range': rang}, f'KD_estimation/KDE_{length}')
# Out:
# 15Oki01
# 15Oki02
# 15Oki03
# 15Oki04
# 15Oki05
# 15Oki06
# 15Oki08
# 15Oki09
# 15Oki10
# 15Oki11
# 15Oki12
# 15Oki13
# 15Oki14
# 15Oki15
# 15Oki16
# 15Oki17
# 15Oki19
# 15Oki21
# 15Oki22
# 15Oki23
# 15Oki24
# 15Oki25
# 15Oki26
# 15Oki27
# 15Oki29
# 15Oki40
# 18Oki01
# 18Oki02
# 18Oki03
# 18Oki04
# 18Oki05
# 18Oki06
# 18Oki07
# 18Oki08
# 18Oki09
# 18Oki10
# 18Oki11
# 18Oki12
# 18Oki13
# 18Oki14
# 18Oki15
# 18Oki16
# 18Oki17
# 18Oki18
# 18Oki19
# 18Oki20
# 18Oki21
# 18Oki22
# 18Oki23
# 18Oki24
# 18Oki25
# 18Oki26
# 18Oki27
# 18Oki28
# 18Oki29
# 18Oki30
# 18Oki31
# 18Oki32
# 18Oki33
# 18Oki34
# 18Oki35
# 18Oki36
# 19Oki01
# 19Oki02
# 19Oki05
# 19Oki07
# 19Oki09
# 19Oki12
# 19Oki13
# 19Oki14
# 19Oki15
# 19Oki16
# 19Oki17
# 19Oki18
# 19Oki20
# 19Oki22
# 19Oki23
# 19Oki24
# 19Oki25
# 15Oki01
# 15Oki02
# 15Oki03
# 15Oki04
# 15Oki05
# 15Oki06
# 15Oki08
# 15Oki09
# 15Oki10
# 15Oki11
# 15Oki12
# 15Oki13
# 15Oki14
# 15Oki15
# 15Oki16
# 15Oki17
# 15Oki19
# 15Oki21
# 15Oki22
# 15Oki23
# 15Oki24
# ...

# %%
labels  = [r'$br_{spacing,1}$ ($cm$)', r'$br_{spacing,2}$ ($cm$)']
bw = 0.05
lengths = ['br_spacing1', 'br_spacing2']
for i,sphere in enumerate(lengths):
    data = load_data.readPickle(f'KD_estimation/KDE_{sphere}')
    lines = data['lines']
    rang = data['range']
    fig = plotKDE(lines, rang, species_info,xlabel = labels[i])
    plt.savefig(f'{vtk.DIR_FIG}/KDE/KDE_{sphere}.pdf', dpi = DPI)
